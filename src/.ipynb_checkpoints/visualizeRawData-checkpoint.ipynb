# %%
import pandas as pd 
import missingno as msno

# %%
# %matplotlib inline

# %%
df = pd.read_excel("../Mice_Dataset/BeiMiceTemp.xlsx", sheet_name="Temps", skiprows=1, squeeze=True, header=0)

# %%
msno.matrix(df, labels=True)
# Out:
# <AxesSubplot:>
