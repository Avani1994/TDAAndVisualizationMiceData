# %%
import pandas as pd 
import missingno as msno

# %%
# %matplotlib inline

# %%
df = pd.read_excel("../Mice_Dataset/BeiMiceTemp.xlsx", sheet_name="Temps")

# %%
msno.matrix(df, labels=True)
# Out:
# <AxesSubplot:>
